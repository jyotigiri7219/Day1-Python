# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotigiri7219/Day1-Python/blob/main/DAY2_PY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Built in fnction**

# %% [markdown]
# **abs () function**  :

# %%
x = abs(-2.25)
print(x)
# Out:
# 2.25

# %%
y = abs(2+5j) #complex number
print(y)
# Out:
# 5.385164807134504

# %% [markdown]
# **Bin function**

# %%
x = bin(13)
print(x)
# Out:
# 0b1101

# %%
y = bin(36)
print(y)
# Out:
# 0b100100

# %% [markdown]
# **Pthon bytes function**

# %%
x = bytes(4)
print(x)
# Out:
# b'\x00\x00\x00\x00'

# %% [markdown]
# **Python chr() function**

# %%
x = chr(97)
print(x)
# Out:
# a

# %%
y = chr(85)
print(y)
# Out:
# U

# %% [markdown]
# **complex function**

# %%
x = complex(3,5)
print(x)
# Out:
# (3+5j)

# %%
y = complex(2.5,3.36)
print(y)
# Out:
# (2.5+3.36j)

# %%
z = complex('2')
print(z)
# Out:
# (2+0j)

# %% [markdown]
# **float function**

# %%
x = float(25)
print(x)
# Out:
# 25.0

# %%
y = float(2.55)
print(y)
# Out:
# 2.55

# %% [markdown]
# **int function**

# %%
x = int(12.25) #folat to intger change
print(x)
# Out:
# 12

# %% [markdown]
# **str() function**

# %%
a = str(2568)
print(a)
print(type(a))
# Out:
# 2568
# <class 'str'>

# %%
a = str(25.68)
print(a)
print(type(a))
# Out:
# 25.68
# <class 'str'>

# %% [markdown]
# **help()function**

# %%
help(float)
# Out:
# Help on class float in module builtins:
#
# class float(object)
#  |  float(x=0, /)
#  |
#  |  Convert a string or number to a floating-point number, if possible.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __ceil__(self, /)
#  |      Return the ceiling as an Integral.
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(self, /)
#  |      Return the floor as an Integral.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Formats the float according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getnewargs__(self, /)
#  |
# ...

# %% [markdown]
# **input function**

# %%
x = input("enter you name")
print( "hello", x)
# Out:
# enter you namejyo
# hello jyo

# %%
x = input("enter you name")
print( "hello", x)
y = input("enter your age")
print("your age is",y)
# Out:
# enter you namejy
# hello jy
# enter your age25
# your age is 25

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          str        25.68
# x          str        jy
# y          str        25
# z          complex    (2+0j)
