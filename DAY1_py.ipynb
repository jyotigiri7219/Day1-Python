# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotigiri7219/Day1-Python/blob/main/DAY1_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VARIABLES

# %%
print("welcom to python")
# Out:
# welcom to python

# %%
x = "jyoti"
print(x)
# Out:
# jyoti

# %%
104 = 2
# Out:
#   File "/tmp/ipykernel_25962/2018396225.py", line 1
#     104 = 2
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# **many values to multiple variables**

# %%
x,y,z = "orange","apple","mango"
print(x,y,z)
# Out:
# orange apple mango

# %%
x = y = z="orange"
print(x)
print(y)
print(z)
# Out:
# orange
# orange
# orange

# %% [markdown]
# ⚓ **python output varibles**

# %%
x = "python"
y = "is so"
z= "esay!"
print(x,y,z)

print()

print(x)
print(y)
print(z)
# Out:
# python is so esay!
#
# python
# is so
# esay!

# %% [markdown]
# **DATA TYPES**

# %%
x = 5
print(x)
print(type(x))
# Out:
# 5
# <class 'int'>

# %%
y = 8.6
print(y)
print(type(y))
# Out:
# 8.6
# <class 'float'>

# %%
z = "jyoti"
print(z)
print(type(z))
# Out:
# jyoti
# <class 'str'>

# %%
a = 2*5j
print(a)
print(type(a))
# Out:
# 10j
# <class 'complex'>

# %%
x = [1,2,5,6,2]
print(x)
print(type(x))
# Out:
# [1, 2, 5, 6, 2]
# <class 'list'>

# %%
x = (1,2,5,6,2)
print(x)
print(type(x))
# Out:
# (1, 2, 5, 6, 2)
# <class 'tuple'>

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          complex    10j
# age        int        25
# b          int        0
# name       int        26
# x          tuple      n=5
# y          float      8.6
# z          str        jyoti

# %% [markdown]
# **bold text**
